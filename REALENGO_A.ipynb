# %%
cerrar= False
while cerrar ==False:
  print("Hola, Soy Realengo ¡hagamos un cuento de Tierra Adentro!")
  print("¿Que te tocó hacer para nuestro cuento?: ")
  print("  A. Describir personajes")
  print("  B. Describir el Camino Real")
  print("  C. Hacer diálogo 1")
  print("  D. Hacer dialógo 2")
  print("  E. Hacer un final diferente")
  respuesta = input("Me tocó la opción: ")
  opcion=respuesta.lower()
  if opcion!='a' and opcion!='b' and opcion!='c' and opcion!='d'and opcion!='e':
    print(" Opción no válida. Vuelve a ingresar una opción")
  if opcion=='a':
    A1 = input("Describe fisicamente al Mellado ¿por qué era así?: ")
    A2 = input("Cómo vestía el Mellado ¿por qué vestía así?: ")
    A3=  input("Qué le gustaba hacer al Mellado y por qué?: ")
    A4= input ("Que le molestaba al Mellado y por qué?: ")
    print("""¡Bien, terminaste tu parte!...
            Tu párrafo quedará así: """)
    ParrafoA=print(f''' El Mellado era {A1},
                  vestía {A2},
                  le gustaba {A3} y
                  le molestaba {A4}''')
    verifi=input('¿Quieres cambiar algo?(si/no)')
    if verifi=='no':
      print("Muy bien. Espera a que terminen los otros equipos")
      cerrar=True
    else:
      cerrar =False

  if opcion=='b':
    B1 = input("Describe fisicamente al Camino Real(vegetación, ríos, clima):")
    B2 = input("¿Cómo eran los parajes más bonitos del Camino Real?:")
    B3=  input("¿Cómo eran los parajes más peligrosos del Camino Real?")
    B4= input("¿Quienes pasaban por el Camino Real y por qué motivo viajaban?")
    print("""¡Bien, terminaste tu parte!...
            Tu párrafo quedará así: """)
    ParrafoA=print(f''' El Camino real tenía {B1},
                  Los parajes más bonitos eran {B2},
                  También tenía parajes peligosos eran {B3} y
                  Por el camino real  pasaban {B4}''')
    verifiB=input('¿Quieres cambiar algo?(si/no)')
    if verifiB=='no':
      print("Muy bien. Espera a que terminen los otros equipos")
      cerrar=True
    else:
      cerrar =False

  if opcion=='c':
    print("Escribe un diálogo del Mellado con sus amigos donde le preguntan qué hará con la ropa que se había robado")
    C1 = input("Amigos: ")
    C2=  input("Mellado:")
    C3= input ("Amigos:")
    C4=  input("Mellado:")
    print ("¡Continua con tu diálogo! Pregunta al Mellado si no se sentía mal por haber robado")
    C5 = input("Amigos: ")
    C6=  input("Mellado:")
    C7= input("Amigos:")
    C8=  input("Mellado:")
    Cfollow= input("¿quieres agregar otro diálogo entre el Mellado y sus amigos?(si/no)")
    if Cfollow=='no'or Cfollow=='No' or Cfollow=='NO':
      print("""¡Bien, terminaste tu parte!...
            Tu párrafo quedará así: """)
      print(f''' Los amigos del Mellado estaban preocupados por él,
      le preguntaban con curiosidad sobre sus asaltos
                  - {C1}
                  - {C2}
                  - {C3}
                  - {C4}
      Otros le preguntaban si no le causaba remordimiento quitarle sus cosas a los demás.
                  - {C5}
                  - {C6}
                  - {C7}
                  - {C8}''')
    if Cfollow=='si'or Cfollow=='SI'or Cfollow=='Si':
      DialogoEx=input("Describe de qué tratará tu diálogo: ")
      C9 = input("Amigos: ")
      C10=  input("Mellado:")
      C11= input("Amigos:")
      C12=  input("Mellado:")
      print("""¡Bien, terminaste tu parte!...
            Tu párrafo quedará así: """)
      print(f''' Los amigos del Mellado estaban preocupados por él,
      le preguntaban con curiosidad sobre sus asaltos
                  - {C1}
                  - {C2}
                  - {C3}
                  - {C4}
      Otros le preguntaban si no le causaba remordimiento quitarle sus cosas a los demás.
                  - {C5}
                  - {C6}
                  - {C7}
                  - {C8}
                   {DialogoEx}
                   {C9}
                   {C10}
                   {C11}
                   {C12}
                   ''')
    verifiC=input('¿Quieres cambiar algo?(si/no)')
    if verifiC=='no'or verifiC=='NO' or verifiC=='No':
      print("Muy bien. Espera a que terminen los otros equipos")
      cerrar=True
      Cfollow='no'
    if verifiC=='si'or verifiC=='Si'or verifiC=='SI':
      cerrar=False
      Cfollow='no'

  if opcion=='d':
    print("El defensor del Mellado pidió hablar con el alcalde mayor para evitar que lo sentenciara a muerte.")
    D1 = input("defensor: ")
    D2=  input("Alcalde mayor:")
    D3= input ("defensor:")
    D4=  input("alcalde mayor:")
    print("""¡Continua con tu diálogo! El defensor del Mellado insistió diciendole que la sentencia de muerte
    causaria mucho dolor entre las personas del pueblo:""")
    D5 = input("Defensor: ")
    D6=  input("Alcalde mayor:")
    D7= input("defensor:")
    D8=  input("Alcalde mayor:")
    Dfollow= input("¿Quieres agregar otro diálogo entre el defensor y sus el elcalde mayor?(si/no)")
    if Dfollow=='no'or Dfollow=='No' or Dfollow=='NO':
      print("""¡Bien, terminaste tu parte!...
            Tu párrafo quedará así: """)
      print(f''' "El defensor del Mellado pidió hablar con el alcalde mayor
      para evitar que lo sentenciara a muerte
                  - {D1}
                  - {D2}
                  - {D3}
                  - {D4}
    El defensor del Mellado insistió diciendole que la sentencia de muerte
    causaria mucho dolor entre las personas del pueblo:
                  - {D5}
                  - {D6}
                  - {D7}
                  - {D8}''')
    if Dfollow=='si'or Dfollow=='SI'or Dfollow=='Si':
     DialogoExD=input("Describe de qué tratará tu diálogo: ")
     D9 = input("Defensor: ")
     D10=  input("Alcalde:")
     D11= input("Defensor:")
     D12=  input("Alcalde:")
     print("""¡Bien, terminaste tu parte!...
            Tu párrafo quedará así: """)
    print(f''' El defensor del Mellado pidió hablar con el alcalde mayor
      para evitar que lo sentenciara a muerte
                  - {D1}
                  - {D2}
                  - {D3}
                  - {D4}
    El defensor del Mellado insistió diciendole que la sentencia de muerte
    causaria mucho dolor entre las personas del pueblo:
                  - {D5}
                  - {D6}
                  - {D7}
                  - {D8}
                   {DialogoExD}
                   {D9}
                   {D10}
                   {D11}
                   {D12}
                   ''')
  verifiD=input('¿Quieres cambiar algo?(si/no)')
  if verifiD=='no'or verifiD=='NO' or verifiD=='No':
      print("Muy bien. Espera a que terminen los otros equipos")
      cerrar=True
      Dfollow='no'
  if verifiD=='si'or verifiD=='Si'or verifiD=='SI':
    cerrar=False
    Dfollow='no'

  if opcion=='e':
    Dinical = input("Escribe un nuevo final para el Mellado")
    cerrar=True
# Out:
# Hola, Soy Realengo ¡hagamos un cuento de Tierra Adentro!
# ¿Que te tocó hacer para nuestro cuento?:
#   A. Describir personajes
#   B. Describir el Camino Real
#   C. Hacer diálogo 1
#   D. Hacer dialógo 2
#   E. Hacer un final diferente
# Me tocó la opción: a
# Describe fisicamente al Mellado ¿por qué era así?: asdf
# Cómo vestía el Mellado ¿por qué vestía así?: asdf
# Qué le gustaba hacer al Mellado y por qué?: asdf
# Que le molestaba al Mellado y por qué?: asdfg
# ¡Bien, terminaste tu parte!...
#             Tu párrafo quedará así:
#  El Mellado era asdf,
#                   vestía asdf,
#                   le gustaba asdf y
#                   le molestaba asdfg
# ¿Quieres cambiar algo?(si/no)no
# Muy bien. Espera a que terminen los otros equipos
# ¿Quieres cambiar algo?(si/no)no
# Muy bien. Espera a que terminen los otros equipos
